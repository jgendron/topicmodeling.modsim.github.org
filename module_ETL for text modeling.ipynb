# %%
'''
Purpose:
Create the final dataset for analysis with an ETL module
* Extract parameters about all MODSIM papers published from 2014 to 2018
* Transform parameters within a dataframe
* Load the text of the MODSIM papers into a working data set

Inputs:
The inputs for this procedure include:
* A list of MODSIM websites containing the papers for parsing HTML with BeautifulSoup
* Text files containing full text from each MODSIM Papers (2014 to 2018)
  ** Downloaded PDF from MODSIM website using Google Chrono Sniffer extension
  ** Converted to text using Mac OS Automator workflow
  ** Assumes a file structure ./data/<year>/ exists for years 2014-2018

Output:
The results of this module is a folder called ./data/abstracts/ containing .txt files each with a custom label and containing abstracts extracted from MODSIM papers.
'''

import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
from random import *
import re

# Provide list of all sites containing MODSIM Papers 2014-2018
sites = ['http://modsimworld.org/conference-papers/2014',
         'http://modsimworld.org/conference-papers/2015',
         'http://modsimworld.org/conference-papers/2016',
         'http://modsimworld.org/conference-papers/2017',
         'http://modsimworld.org/conference-papers/2018']
# Create an empty list to capture webscrape results 
records = [] 

# Extract: get parameters of papers into a dataframe
for site in sites:
    page = requests.get(site)
    soup = BeautifulSoup(page.text, 'html.parser')
    results = soup.find_all('table') # finds all tables on page, each is a track

    for result in results:
        for r in result.findAll('tr'):
            if r.find('td') is not None:
                track = result.find('th').text
                filename = r.find('a')['href'][13:]
                author = r.find('td').text
                team = round((len(r.find('td').text) +\
                              randint(-2,2)),0) #jitter added for six duplicate labels
                title = r.find('span').text
                year = r.find('a')['href'][8:12]
                records.append((track,filename,author,team,title,year))

df = pd.DataFrame(records, columns = ['track', 'filename', 'author_id', 'team','title', 'year'])

# Transform: relabel tracks into one of four categories
df['year'] = df['year'].apply(str)
mapped_sub = {'track': {'Training and Education': 'TE',
                        'Training': 'TE',
                        'Education': 'TE',
                        'Analytics and Decision Making': 'AT',
                        'Analytics and Decision-Making': 'AT',
                        'Science and Engineering': 'SE',
                        'Visualization and Gamification': 'VG',
                        'Entertainment, Sports, Media, & Visualization': 'VG',
                        'Cyber Security': 'VG'}
             }
df_mod = df.replace(to_replace=mapped_sub)

# Transform: convert .pdf filenames into .txt
df_mod['filename'] = df_mod['filename'].str.replace('pdf', 'txt')

# Transform: extract first occurence of last name as author tag
# create three individual series for three types of matches
a=df_mod['author_id'].str.extract(r'([a-zA-Z]+,)')
b=df_mod['author_id'].str.extract(r'([a-zA-Z]+ and)')
c=df_mod['author_id'].str.extract(r'([a-zA-Z]+$)')

# combine the three temp series with precedence for already filled rows
temp = a.combine_first(b).combine_first(c)
# remove the separator flags 
temp[0] = temp[0].str.replace(',','') # a series function
temp[0] = temp[0].str.replace(' and','')
df_mod['author_id'] = temp[0]

#Transform: convert team variable to string
df_mod['team'] = df_mod['team'].apply(str)

# Create doc labels in track-year-author format  
df_mod['label'] = './data/abstracts/' + df_mod['track'] + '-' + \
                df_mod['year'] + '-' + df_mod['author_id'] + \
                '[' + df_mod['team']  + '].txt'


# Create a zipped object of tuples (filename, label) to iterate through files
tup = zip(df_mod['filename'],df_mod['label'])

for file,label in tup:
    #create filename to open text file of MODSIM paper
    filename = './data/papers_text/' + label[20:24] + '/' + file
    try:
        f = open(filename, encoding='latin')
        raw = f.read()
    except ValueError:
        print(f'X: {filename}')
    
    abstract = re.search('ABSTRACT\n',raw)
    if not abstract:
        print(f'Need abstract tag: {filename}')
    author = re.search('ABOUT THE', raw)
    if not author:
        print(f'Need author tag: {filename}')
        
    begin = re.search('ABSTRACT\n', raw) #flag for beginning of abstract
    stop = re.search('ABOUT THE', raw) #flag for stop of abstract
    #ironic but we want the end of the begin flag and start of stop flag
    abstract = raw[begin.end():stop.start()] #extracts the abstract
    f.close()
    print(f'Opening {file} and extracting abstract') #output to show progress
    
    #Write the extracted abstract to text file 
    text = open(label, "w")
    text.write(abstract)
    text.close()
    print(f'Writing extracted abstract as file {label}\n') #output to show progress
# Out:
# Opening MS1401-Pratical HSI Methods for Medical Simulation Sim_NOLAN - udpated_8 April.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2014-Bockelman[90].txt
#
# Opening MS1480-Decision Making MODSIM 2014 Paper.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2014-Hase[52].txt
#
# Opening MODSIM2014_MIST_INSPYRED_Paper_Submit_2014_03_10.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2014-Barhak[39].txt
#
# Opening SCDT_MODSIM Paper.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2014-Allen[110].txt
#
# Opening MS1470_MODSIM_2014_Massed Exposure Improves Response Time_Salcedo_Lackey_Reinerman-Jones.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2014-Lackey[78].txt
#
# Opening 2013 Virginia Homeland Security Portfolio Value Model March 2014.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2014-Ezell[36].txt
#
# Opening MODSIM2014_LVCGAED.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2014-Brun[97].txt
#
# Opening SpecializedTankInspectionandOverhaul.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2014-Drucker[40].txt
#
# Opening Equal but Different_20140312_SJL.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2014-Lackey[81].txt
#
# Opening Final Energy Resilience MODSIM 2014 Paper_14 Mar 14.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2014-Delaney[65].txt
#
# Opening MODSIM_World_2014_CoL_ Fautua Schatz et al 16Mar14 -FINAL.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Bockelman[106].txt
#
# Opening MS1421-Knowledge Quest (Gendron and Friedman).txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Friedman[44].txt
#
# Opening 1484_Hulme_04042014.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Fabiano[92].txt
#
# Opening MODSIM_World_2014_Schatz_Colombo_Graffeo_Bolton_-_Perceptual_Taxonomy.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Bolton[75].txt
#
# Opening MODSIM World 2014 Paper number 1478 April 7 2014.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Rosacia[68].txt
#
# Opening 2014 - Modsim - VOR-zFinal.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Croll[103].txt
#
# Opening MODSIM collins paper.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2014-Ball[69].txt
#
# Opening AIMS_ModSim_Paper_2014CawrseFinal.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2014-Cawrse[44].txt
#
# Opening Modsim2014_Paperv3.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2014-Aras[58].txt
#
# Opening MODSIM_World_2014_Lenuik_Murley_v2.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2014-Lenuik[45].txt
#
# Opening SIVL_MODSIM.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2014-Buttrill[50].txt
#
# Opening ModSimWorld_2014_Mook_ManufacturingSim_Final.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2014-Mook[22].txt
#
# Opening Lin_Watson_MODSim2014_Submitted2.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2014-Lin[39].txt
#
# Opening MODSIM World 2014 Riverscout_Jesse_Barboza 041114.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2014-Barboza[79].txt
#
# Opening Lackey_Badillo-Urquiola_Ortiz_1475.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2014-Urquiola[71].txt
#
# Opening INS Modsim World Paper - Final.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2014-Croll[142].txt
#
# Opening MODSIMWorld-2014-1964C.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2014-Heath[97].txt
#
# Opening MODSIM World 2014 Developing an Ultrasonography Simulator Training Tool Final.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2014-Banks[98].txt
#
# Opening 1472_MITLincolnLabs_MSW2014.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2014-Carter[95].txt
#
# Opening Utilizing Real Test Sets on Maintenance Training Devices.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Ferrell[27].txt
#
# Opening MODSIM World 2014 Rebarick et al final.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Bowers[68].txt
#
# Opening MS1420-Commercial Games Trends in NATO (Gendron).txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Buck[68].txt
#
# Opening MODSIM World 2014 Paper ARC-231 Development - MOORE.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Ferrell[35].txt
#
# Opening MODSIM World 2014 Paper (Stevens & Kincaid) - 30 Jan 14.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Kincaid[43].txt
#
# Opening edcss-openeaagles-rev2.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Holdzkom[68].txt
#
# Opening Reflecting on Cognitive Process Models to Enhance Adaptive Training.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Allison[59].txt
#
# Opening ModSimWorld2014_AFMS Sim 101 and 201_Paper_v6.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Gardner[83].txt
#
# Opening MODSIM_World_2014_Paper_Large_Scale_Exercise_Planning.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2014-Kent[34].txt
#
# Opening A_General_Purpose_Geospatial_Encounter_Prediction_Model_for_Border_Security.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2015-Harvey[76].txt
#
# Opening An_Adaptive_Planning_Tool_for_Ship_Construction_Warehouse_Capacities.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2015-Drucker[40].txt
#
# Opening Evaluation_of_Submarines_Tactical_Operations_Using_Heterogeneous_Models.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2015-Bang[41].txt
#
# Opening Foreign_Fishing_Vessel_Impact_Analysis.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2015-Denicola[57].txt
#
# Opening Fundamental_Building_Blocks_for_Vehicle-Pedestrian_Interaction_in_Emergency_Evacuations.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2015-Elzie[87].txt
#
# Opening Natural_Language_Processing.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2015-Gendron[23].txt
#
# Opening Object_Oriented_Population_Generation.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2015-Barhak[15].txt
#
# Opening Terrisk_Battling_Uncertainty_in_Bioterrorism_Models.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2015-Gore[35].txt
#
# Opening Tradecraft_and_Analysis_Learning_using_Intelligence_Scenarios_with_Methods-Anchoring.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2015-Bell[38].txt
#
# Opening Web_Enabled_Selection_Method_for_Key_Performance_Indicators_for_Manufacturing.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2015-Lawsure[94].txt
#
# Opening Mixed_Reality_The_New_Reality_in_DoD_Decision_Making.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2015-Lenuik[105].txt
#
# Opening Training_for_the_Combined_Cyber_Kinetic_Battlefield.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2015-Wihl[13].txt
#
# Opening An_Agile_Roadmap_for_Live_Virtual_Constructive-Integrating_Training_Architecture.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2015-Park[68].txt
#
# Opening An_LVC_Simulation_Interoperability_Measurement_Framework.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2015-Kim[67].txt
#
# Opening Credibility_of_Modeling_and_Simulation_via_Triangulation.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2015-Balaban[21].txt
#
# Opening Employing_High_Performance_Computing_to_Realize_a_Cyber_Quick-Reaction_Training_Environment.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2015-Castello[91].txt
#
# Opening Emulytics_at_Sandia_National_Laboratories.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2015-Urias[81].txt
#
# Opening Generating_Large_Deterministic_Water_Waves_for_Numerical_Simulation.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2015-Alford[47].txt
#
# Opening Ontological_Support_to_Address_the_Multi-Dimensionality_of_Complex_Systems_Engineering_Challenges.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2015-Tolk[53].txt
#
# Opening Person-Centered_Medical_and_Healthcare_Studies.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2015-Gore[43].txt
#
# Opening Quantifying_Performance_between_Tele-Operated_and_Supervised_Autonomous_Fire_Control.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2015-Wheeler[60].txt
#
# Opening Rediscover_the_Defense_MS_Catalog.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2015-Rutherford[39].txt
#
# Opening Simulated_Human_Tissue_Performance.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2015-Norfleet[64].txt
#
# Opening The_Virtual_Test_Bed.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2015-Nhan[55].txt
#
# Opening Augmenting_Training_of_the_Humeral_Head_Intraosseous_Procedure_with_a_High_Fidelity_Anatomical_Model.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2015-Alban[44].txt
#
# Opening Developing_Interoperable_Data_for_Training_Effectiveness_Assessment_in_Army_Marksmanship_Training.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2015-Murphy[85].txt
#
# Opening Everything_I_Ever_Needed_to_Know_About_Simulation_and_Training_I_Learned_from_Enders_Game.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2015-Pike[52].txt
#
# Opening Higher_Order_mLearning.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2015-McCann[17].txt
#
# Opening Leveraging_Virtualization_Technology_for_Command_and_Control_Systems_Training.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2015-Connery[60].txt
#
# Opening Mission_Requirements_Based_Combat_Flight_Simulator_Selection.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2015-z[40].txt
#
# Opening Modeling_Proxemic_Cues_for_Simulation-Based_Training_in_Virtual_Environments.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2015-Maraj[104].txt
#
# Opening Research_and_Development_of_Low-Cost_Point_of_Injury_Medical_Simulations.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2015-Hackett[60].txt
#
# Opening The_Impact_of_Training_Context_on_Performance_in_Simulator-Based_Aviation_Training.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2015-Walker[18].txt
#
# Opening Transforming_e-Learning_into_o-Learning.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2015-Fautua[35].txt
#
# Opening Analyzing_Eye-Tracking_Accuracy_with_and_without_Cursor_Feedback_for_use_in_a_Simulated_Robotic_Search_Task.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2015-Papelis[62].txt
#
# Opening Augmenting_Part-Task_Training_Simulators_with_Games.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2015-Santarelli[47].txt
#
# Opening Dynamically_Coupled_3D_Visualization_and_Real-time_Simulation_as_an_Aid_to_Developing_Mental_Models_of_Sonar.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2015-Summers[69].txt
#
# Opening Gamification_and_Visualization_of_Sensor_Data_Analysis_in_Research_Buildings.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2015-Stone[83].txt
#
# Opening Medical_Virtual_Integrated_Training_Environment.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2015-Rusnak[99].txt
#
# Opening Migration_of_the_Maritime_Simulation_Model_2_into_a_Force-on-Force_Federated_Simulation_Architecture.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2015-Schneider[62].txt
#
# Opening Tools_for_Cultural_Intelligence_Development.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2015-Santarelli[104].txt
#
# Opening Seriously_Mobile_Downloadable_Content_in_Serious_Games.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2015-Morabito[19].txt
#
# Opening Virtual_Environments_The_Prompt_Jump_for_the_Next_Generation_Energy_Workforce.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2015-Nesselrode[18].txt
#
# Opening Visualization_and_Animation_for_Teaching_Frank-Wolfe_Transportation_Network_Equilibrium.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2015-Li[91].txt
#
# Opening A_Hybrid_Metaheuristic_Algorithm_for_Multi-Objective_Runway_Scheduling_Problem_in_Simulation-based_Optimization.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2016-Soykan[47].txt
#
# Opening Animal_Disease_Spread_Modeling_for_Epidemiological_and_Economics.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2016-Schoenbaum[80].txt
#
# Opening Techniques_and_Applications_to_Transform_Army_Learning.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2016-Long[90].txt
#
# Opening Data_Farming_and_Quantitative_Analysis_of_Cyber_Defense_Technologies_and_Measures.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2016-Horne[43].txt
#
# Opening How_to_Simulate_Field_Data_in_the_Lab.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2016-Gendron[56].txt
#
# Opening Mahalanobis_Taguchi_System_for_Pattern_Recognition_Prediction_and_Optimization.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2016-Holcomb[20].txt
#
# Opening Modeling_and_Simulation_of_an_Integrated_Gate_Turnaround_Management_Concept.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2016-Chung[101].txt
#
# Opening Optimizing_Model_Combinations.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2016-Barhak[63].txt
#
# Opening Representation_Selection_and_Scheduling_of_Training_in_a_Lifelong_Learning_Context.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2016-Carlin[57].txt
#
# Opening Utilization_Data_is_needed_to_Reduce_Training_Device_Costs.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2016-Kent[13].txt
#
# Opening A_Human-Centered_Approach_to_Modeling_Security_Information_and_its_Impact_on_Cargo_Operations.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2016-Braxton[77].txt
#
# Opening An_Adaptive_Planning_Tool_for_Ship_Construction_and_Material_Logistics.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2016-Campbell[17].txt
#
# Opening Cellular_Dynamics_During_Epicutaneous_Immunotherapy_Using_Agent_Based_Modeling.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2016-Hinton[19].txt
#
# Opening Electrolyte_Concentration_Dependence_of_Ion_Transport_through_Nanochannels.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2016-Bakirci[36].txt
#
# Opening Framework_for_ADAPT_Simulated_Testing.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2016-Condotta[225].txt
#
# Opening Modeling_and_Simulation_Tools_for_Heavy_Lift_Airships.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2016-Hochstetler[101].txt
#
# Opening Physics_Engine_Benchmarking_in_Three-Dimensional_Virtual_World_Simulation.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2016-Mondesire[103].txt
#
# Opening Supporting_Ship_Overhaul_with_Customized_Discrete_Event_Simulation.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2016-Shaffer[45].txt
#
# Opening A_comparison_of_the_mechanical_properties_of_human_pleura_vs_synthetic_training_pleura.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2016-Norfleet[120].txt
#
# Opening Rule_Extraction_and_Visualization_from_Data_Traces.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2016-Koola[78].txt
#
# Opening Developing_Simulation-Based_Training_for_Client_Assessment_Interviewing_in_Social_Work.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2016-Hill[61].txt
#
# Opening Learning_Experience_Design_Challenges_and_Opportunities.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2016-Raybourn[20].txt
#
# Opening A_Case_Study_in_Establishing_Multinational_Simulator_Interoperability.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2016-Seavey[125].txt
#
# Opening Building_an_Efficient_e-Learning_Team.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2016-Trammell[41].txt
#
# Opening Development_and_Evaluation_of_a_High_Fidelity_Anatomical_Model_for_the_Humeral_Head_Intraosseous_IO_Procedure.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2016-Sotomayor[63].txt
#
# Opening Evaluating_Adaptive_Training_for_Teams_using_the_Experience_API.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2016-Long[140].txt
#
# Opening High-Fidelity_Training_on_Demand_via_the_Cloud.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2016-Bair[59].txt
#
# Opening Next_Generation_Venipuncture_and_Phlebotomy_High_Fidelity_Training_System.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2016-Sotomayor[61].txt
#
# Opening Semantic_and_Episodic_Learning_to_Integrate_Diverse_Opportunities_for_Life-Long_Learning.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2016-Kovarik[79].txt
#
# Opening Tailored_Cybersecurity_training_in_LVC_environments.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2016-Nicholson[78].txt
#
# Opening Using_an_Analytical_Approach_to_Understand_Integrated_Training_Environment_Utility.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2016-Hodges[22].txt
#
# Opening A_Game-based_ModSim_Environment_with_Implementation_to_Examine_Task-Unrelated_Thought_While_Driving.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2016-Hulme[93].txt
#
# Opening Landstown_High_School_Governors_STEM_Academy_Modeling_and_Simulation_Pathway.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2016-Barger[60].txt
#
# Opening Reinforcing_Land_Navigation_Outside_the_Classroom.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2016-Tucker[36].txt
#
# Opening Cutting_Cost_by_Increasing_Focus.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2016-Morabito[16].txt
#
# Opening The_Battle_of_Isandlwana.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2016-Reilly[20].txt
#
# Opening Training_Effectiveness_Evaluation_of_Lightweight_Game-based_Constructive_Simulation.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2016-Reed[99].txt
#
# Opening Visualizing_Big_Data.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2016-Haynes[80].txt
#
# Opening Workload_Analysis_of_Virtual_World_Simulatio_for_Military_Training.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2016-Reed[126].txt
#
# Opening A_Foundation_for_a_Modeling_and_Simulation_Digital_Engineering_Ecosystem.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2017-Johnson[64].txt
#
# Opening A_Simulation_on_the_Effect_of_a_Major_World_War_on_the_Population_of_the_World.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2017-Zhang[34].txt
#
# Opening Creating_Teaching_and_Learning_Accountabilities_Through_Data_Analytic_Feedback_Loops.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2017-ahin[38].txt
#
# Opening Data_Farming_and_The_Black_Swan.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2017-Horne[23].txt
#
# Opening Data_Sharing_is_a_Critical_Capability.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2017-Schultz[90].txt
#
# Opening Predictive_analytics_with_an_advanced_Bayesian_modeling_framework.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2017-Kristensen[107].txt
#
# Opening Simulating_Foot-and-Mouth_Disease_in_the_United_States_using_the_Animal_Disease_Spread_Model.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2017-Schoenbaum[105].txt
#
# Opening Simulating_the_Impact_of_Sudarshan_Kriya_Yoga_in_Hampton_Roads.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2017-Nisperos[66].txt
#
# Opening The_Reference_Model_Predicts_Life_Expectancy_for_Diabetics.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2017-Barhak[14].txt
#
# Opening Training_Equipment_Life_Cycle_Awareness_for_Combat_Training_Centers.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2017-Kent[16].txt
#
# Opening United_States_Coast_Guard_Firehouse_Staffing_Analysis.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2017-Long[17].txt
#
# Opening Augmenting_Model-Based_Design_with_the_HEAT_Human_System_Integration_Advisor.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2017-Abrams[36].txt
#
# Opening Data_trace_visualizations_to_decipher_carrier_traffic_patterns.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2017-Koola[46].txt
#
# Opening Experimental_Validation_of_a_ground_robot_simulation_model_during_line_following_task.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2017-Papelis[41].txt
#
# Opening Effective_Cybersecurity_Using_Modeling_&_Simulation.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2017-Gustavson[41].txt
#
# Opening Harmonized_Air_Missile_Space_Training_Environment.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2017-Bizub[59].txt
#
# Opening Modeling_the_Characteristics_of_Radical_Ideological_Growth.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2017-Cummings[47].txt
#
# Opening Case_Study_and_General_Approach_for_Integrating_Learning_Applications.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2017-Freed[61].txt
#
# Opening Rapid_USV_Prototyping_System.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2017-Branch[154].txt
#
# Opening Realism_in_Modeling_and_Simulation_with_Implications_for_VR_AR_and_IE.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2017-Wallace[43].txt
#
# Opening A_Fully_Immersive_VR_Training_System_for_Rocket_Fuel_Mixing_Operations.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Mastaglio[64].txt
#
# Opening Analysis_of_effective_speech_recognition_in_A_Virtual_Operating_Room.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Scerbo[213].txt
#
# Opening Authoring_adaptive_tutors_for_simulations_in_psychomotor_skills_domains.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Brown[62].txt
#
# Opening Leveraging_Web-Based_Global_MS_Terrain_Repositories_for_Scenario_Development.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Chambers[57].txt
#
# Opening Effectiveness_of_AR_and_VR.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Fletcher[90].txt
#
# Opening Evaluating_Game-Based_Environments_for_Army_Aviation_Collective_Training.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Jones[122].txt
#
# Opening Experiential_Correlation_of_Vehicle_Dynamics_Simulation_to_Self-reported_Driving_Learning_and_Gaming_styles.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Hulme[68].txt
#
# Opening Improving_the_Utility_of_Open-Source_Event_Data_for_the_Design_of_Training_Exercises.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Murphy[81].txt
#
# Opening Joint_Staff_J7_Joint_Training_Tools_for_Campaign_Planning.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Grom[72].txt
#
# Opening Just_a_Shiny_Object.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Armendariz[83].txt
#
# Opening Large_Scale_Testing_and_Evaluation_of_Virtual_Environments_for_Infantry_Soldier_Tasks.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Maxwell[41].txt
#
# Opening Semantic_Instrumentation_of_Virtual_Environments_for_Training.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Greuel[58].txt
#
# Opening System_of_Systems_Approach_for_the_Development_of_Next_Generation_Modular_Simulation-Based_Training_Systems.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Burwell[35].txt
#
# Opening Using_Combat_Adjudication_to_Aid_in_Training_for_Campaign_Planning.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Grom[56].txt
#
# Opening Integrated_After_Action_Review_System_for_Mobile_Medical_Lane_Training.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Honold[80].txt
#
# Opening Utilizing_Force_Management_Service_to_Support_Realistic_Training.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Babb[55].txt
#
# Opening Validation_of_the_Course_for_Operationally_Relevant_Patient_Safety.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2017-Parodi[71].txt
#
# Opening Analysis_of_Team_Tutoring_Training_Data.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2017-MacAllister[140].txt
#
# Opening Cultivating_Digital_TLC_Teaching_and_Learning_Communities.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2017-Mentor[18].txt
#
# Opening Leveraging_HTML5_and_WebGL_to_Address_Information_Assurance_Barriers_for_Simulation_Based_Training_in_the_US_Military.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2017-Maxwell[44].txt
#
# Opening Modeling_the_Economic_Impact_of_Foot-and-Mouth_Disease_in_the_US_Using_the_Paarlberg_Quarterly_Economic_Model.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2017-Assefa[73].txt
#
# Opening Navigating_AR_and_VR_Hardware_Choices.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2017-Congdon[41].txt
#
# Opening Using_Low-Cost_Tabletop_Simulation_to_Develop_and_Evaluate_High-Value_CONOPS_in_Uncertain_Tactical_Environment.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2017-Erwin[48].txt
#
# Opening Understanding_Future_Conflict_Escalation_Dynamics_with_Analytic_Gaming.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2017-Lytwyn[18].txt
#
# Opening MODSIM_2018_Axdahl.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2018-Axdahl[17].txt
#
# Opening MODSIM_2018_McCrindle.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2018-McCrindle[20].txt
#
# Opening MODSIM_2018_Nisperos.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2018-Nisperos[49].txt
#
# Opening MODSIM_2018_Barhak.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2018-Barhak[17].txt
#
# Opening MODSIM_2018_Gendron_Weisel.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2018-Gendron[57].txt
#
# Opening MODSIM_2018_Tavel_Markovits.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2018-Tavel[38].txt
#
# Opening MODSIM_2018_Schoenbaum_et_all.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2018-Schoenbaum[131].txt
#
# Opening MODSIM_2018_ODU_Capstone.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2018-Richardson[135].txt
#
# Opening MODSIM_2018_Barber_Harris_Dunne_Goodwin_Reinerman.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2018-Barber[115].txt
#
# Opening MODSIM_2018_Horne_Stilwell.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2018-Horne[38].txt
#
# Opening MODSIM_2018_Turscak.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2018-Turscak[19].txt
#
# Opening MODSIM_2018_Surdu_Velazquez.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/AT-2018-Surdu[35].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_5.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2018-Gregory[76].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_10.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2018-Seasly[46].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_14.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2018-Daiker[55].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_19.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2018-Griffith[74].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_26.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2018-Aureliano[116].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_35.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2018-Watson[36].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_36.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2018-Dauble[55].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_52.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2018-Kaimakis[78].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_55.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2018-Franklin[131].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_56.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/SE-2018-Burns[58].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_7.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2018-Bell[58].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_15.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2018-Freeman[18].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_17.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2018-Wismer[122].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_18.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2018-Puskaritz[95].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_22.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2018-Babcock[62].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_23.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2018-Reardon[82].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_24.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2018-Dunne[100].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_29.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2018-Joe[12].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_43.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2018-Goodwin[93].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_44.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2018-Dupre[67].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_50.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2018-Davis[64].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_65.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2018-Klafehn[81].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_66.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/TE-2018-Kiehl[101].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_2.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2018-Swan[14].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_28.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2018-Maxwell[60].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_30.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2018-Hackett[19].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_31.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2018-Leathrum[78].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_48.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2018-Bucioli[85].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_53.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2018-Renduchintala[76].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_59.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2018-Tracey[82].txt
#
# Opening MODSIM_2018_Paper_not_required_for_a_63.txt and extracting abstract
# Writing extracted abstract as file ./data/abstracts/VG-2018-Lackey[60].txt

# %%
# Verify no duplicate labels
len(df_mod['label']) == len(set(df_mod['label']))
# Out:
# True
